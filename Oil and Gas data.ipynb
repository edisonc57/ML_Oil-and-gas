# %%
import pandas as pd

# %%
df= pd.read_csv('https://raw.githubusercontent.com/edisonc57/ML_Oil-and-gas/main/Data/well_18_ml_v1.csv')

# %%
df.head(10)
# Out:
#   wellName    DEPTH       CGR   CPERM       CPHI        DT      DTSM  Facies  \
# 0  A-18-00  852.857   4.91913 -9999.0 -9999.0000   74.5270  121.9698       1
# 1  A-18-00  853.010   9.99433 -9999.0 -9999.0000   88.8155  141.6838       1
# 2  A-18-00  853.162  20.56400 -9999.0 -9999.0000   99.0574  166.7016       5
# 3  A-18-00  853.314  31.71550 -9999.0 -9999.0000  104.7870  182.5868       5
# 4  A-18-00  853.467  37.70880 -9999.0     0.4288  104.8980  185.0199       5
# 5  A-18-00  853.619  35.58090 -9999.0     0.4126   99.2912  178.6600       5
# 6  A-18-00  853.772  28.67900 -9999.0 -9999.0000   91.7247  168.8887       5
# 7  A-18-00  853.924  23.13950 -9999.0 -9999.0000   86.5516  158.7577       5
# 8  A-18-00  854.076  21.04370 -9999.0 -9999.0000   85.1543  153.1469       5
# 9  A-18-00  854.229  21.92050 -9999.0     0.2201   85.8205  153.4092       5
#
#         GR     MSFL      NPHI       PEF  Perm_Buckles_UpAs      PHIE     RHOB  \
# ...

# %%
df= pd.read_csv('https://raw.githubusercontent.com/edisonc57/ML_Oil-and-gas/main/Data/well_18_ml_v1.csv', skiprows=[1,5,8,888], na_values='Nan')

# %%
df.head()
# Out:
#   wellName    DEPTH       CGR   CPERM       CPHI        DT      DTSM  Facies  \
# 0  A-18-00  853.010   9.99433 -9999.0 -9999.0000   88.8155  141.6838       1
# 1  A-18-00  853.162  20.56400 -9999.0 -9999.0000   99.0574  166.7016       5
# 2  A-18-00  853.314  31.71550 -9999.0 -9999.0000  104.7870  182.5868       5
# 3  A-18-00  853.619  35.58090 -9999.0     0.4126   99.2912  178.6600       5
# 4  A-18-00  853.772  28.67900 -9999.0 -9999.0000   91.7247  168.8887       5
#
#         GR     MSFL      NPHI       PEF  Perm_Buckles_UpAs      PHIE     RHOB  \
# 0  53.4034  2.36973  0.151655  4.399977           9.209792  0.146527  2.61065
# 1  72.0957  1.31614  0.231567  4.030700           1.601786  0.220162  2.47339
# 2  78.3783  1.20371  0.287493  3.732858           3.690761  0.276589  2.35818
# 3  58.2256  1.63194  0.269803  3.399365           4.512031  0.291632  2.30063
# 4  50.9648  1.69673  0.237844  3.353567           3.159364  0.265337  2.35175
#
# ...

# %%
df.columns
# Out:
# Index(['wellName', 'DEPTH', 'CGR', 'CPERM', 'CPHI', 'DT', 'DTSM', 'Facies',
#        'GR', 'MSFL', 'NPHI', 'PEF', 'Perm_Buckles_UpAs', 'PHIE', 'RHOB', 'RT',
#        'SWE', 'ZONE_NAME', 'net_gross'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# wellName              object
# DEPTH                float64
# CGR                  float64
# CPERM                float64
# CPHI                 float64
# DT                   float64
# DTSM                 float64
# Facies                 int64
# GR                   float64
# MSFL                 float64
# NPHI                 float64
# PEF                  float64
# Perm_Buckles_UpAs    float64
# PHIE                 float64
# RHOB                 float64
# RT                   float64
# SWE                  float64
# ZONE_NAME             object
# net_gross             object
# dtype: object

# %%
print(df['DEPTH'].dtypes)
# Out:
# float64

# %%
df.describe()
# Out:
#              DEPTH          CGR         CPERM         CPHI           DT  \
# count  1100.000000  1100.000000   1100.000000  1100.000000  1100.000000
# mean    937.087017    22.064474  -9206.400723 -7826.424812  -117.683374
# std      48.459099    14.814662   3005.616648  4125.484284  1476.640692
# min     853.010000    -1.820080  -9999.000000 -9999.000000 -9999.000000
# 25%     895.186000    10.993825  -9999.000000 -9999.000000    80.912975
# 50%     937.058000    19.478800  -9999.000000 -9999.000000    95.359650
# 75%     978.930000    30.318275  -9999.000000 -9999.000000   119.477000
# max    1020.950000    77.795400  24967.240230     0.431600   177.691000
#
#               DTSM       Facies           GR         MSFL         NPHI  \
# count  1100.000000  1100.000000  1100.000000  1100.000000  1100.000000
# mean    229.143479 -3506.061818    33.918802     1.024971     0.285378
# std      79.039704  4776.209015    13.667024     1.872884     0.054746
# ...

# %% [markdown]
#  Si la media y la mediana son similares, sugiere que los datos están simétricamente distribuidos. Si son muy diferentes, podría haber sesgos en los datos.
#
#  Si la desviación estandar es alta, los valores están muy dispersos, lo que puede afectar la capacidad del modelo para generalizar.
#
# Valores mínimos y máximos ayudan a identificar outliers o valores extremos que pueden distorsionar los modelos.

# %%
df[['CGR', 'NPHI', 'RHOB', 'DT']].describe()
# Out:
#                CGR         NPHI         RHOB           DT
# count  1100.000000  1100.000000  1100.000000  1100.000000
# mean     22.064474     0.285378  -325.005545  -117.683374
# std      14.814662     0.054746  1780.261371  1476.640692
# min      -1.820080     0.007749 -9999.000000 -9999.000000
# 25%      10.993825     0.261571     2.174780    80.912975
# 50%      19.478800     0.288147     2.305875    95.359650
# 75%      30.318275     0.318682     2.394730   119.477000
# max      77.795400     0.433466     2.945620   177.691000

# %% [markdown]
# Tabla de estadísticas descriptivas
#
# *count: Es el número de datos o muestras disponibles para cada variable, en este caso, 1100.
#
# *mean: Es el valor promedio de cada variable.
# Ejemplo: El valor promedio de CGR es 22.06.
#
# *std: Es la desviación estándar, que mide la dispersión de los valores respecto al promedio.
# Ejemplo: La desviación estándar de NPHI es 0.054.
#
# *min: Es el valor mínimo registrado para cada variable.
# Ejemplo: El valor mínimo de RHOB es -9999.0, que podría indicar valores faltantes o erróneos.
#
# *25% (Primer cuartil): Es el valor debajo del cual se encuentra el 25% de los datos.
# Ejemplo: El 25% de los datos de DT están por debajo de 80.91.
#
# *50% (Mediana): Es el valor medio o mediana, donde el 50% de los datos están por encima y el 50% por debajo.
# Ejemplo: El valor mediano de CGR es 19.48.
#
# *75% (Tercer cuartil): Es el valor debajo del cual se encuentra el 75% de los datos.
# Ejemplo: El 75% de los datos de RHOB están por debajo de 2.3947.
#
# *max: Es el valor máximo registrado para cada variable.
# Ejemplo: El valor máximo de DT es 177.69.

# %%
df.describe(include=['object'])
# Out:
#        wellName ZONE_NAME net_gross
# count      1100      1100      1100
# unique        1         5         2
# top     A-18-00      Ghar       net
# freq       1100       580       793

# %%
df.describe(include=['float64'])
# Out:
#              DEPTH          CGR         CPERM         CPHI           DT  \
# count  1100.000000  1100.000000   1100.000000  1100.000000  1100.000000
# mean    937.087017    22.064474  -9206.400723 -7826.424812  -117.683374
# std      48.459099    14.814662   3005.616648  4125.484284  1476.640692
# min     853.010000    -1.820080  -9999.000000 -9999.000000 -9999.000000
# 25%     895.186000    10.993825  -9999.000000 -9999.000000    80.912975
# 50%     937.058000    19.478800  -9999.000000 -9999.000000    95.359650
# 75%     978.930000    30.318275  -9999.000000 -9999.000000   119.477000
# max    1020.950000    77.795400  24967.240230     0.431600   177.691000
#
#               DTSM           GR         MSFL         NPHI          PEF  \
# count  1100.000000  1100.000000  1100.000000  1100.000000  1100.000000
# mean    229.143479    33.918802     1.024971     0.285378     2.747468
# std      79.039704    13.667024     1.872884     0.054746     0.621874
# ...

# %%
df.describe(include=['int64'])
# Out:
#             Facies
# count  1100.000000
# mean  -3506.061818
# std    4776.209015
# min   -9999.000000
# 25%   -9999.000000
# 50%       4.000000
# 75%       5.000000
# max       5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   wellName           1100 non-null   object
#  1   DEPTH              1100 non-null   float64
#  2   CGR                1100 non-null   float64
#  3   CPERM              1100 non-null   float64
#  4   CPHI               1100 non-null   float64
#  5   DT                 1100 non-null   float64
#  6   DTSM               1100 non-null   float64
#  7   Facies             1100 non-null   int64
#  8   GR                 1100 non-null   float64
#  9   MSFL               1100 non-null   float64
#  10  NPHI               1100 non-null   float64
#  11  PEF                1100 non-null   float64
#  12  Perm_Buckles_UpAs  1100 non-null   float64
#  13  PHIE               1100 non-null   float64
#  14  RHOB               1100 non-null   float64
# ...

# %% [markdown]
# 2. Data Wrangling
#
# Es el proceso de converting la data de un formato iniciala un formato que puede ser para un mejor analisis

# %%
df.head(10)
# Out:
#   wellName    DEPTH       CGR   CPERM       CPHI        DT      DTSM  Facies  \
# 0  A-18-00  853.010   9.99433 -9999.0 -9999.0000   88.8155  141.6838       1
# 1  A-18-00  853.162  20.56400 -9999.0 -9999.0000   99.0574  166.7016       5
# 2  A-18-00  853.314  31.71550 -9999.0 -9999.0000  104.7870  182.5868       5
# 3  A-18-00  853.619  35.58090 -9999.0     0.4126   99.2912  178.6600       5
# 4  A-18-00  853.772  28.67900 -9999.0 -9999.0000   91.7247  168.8887       5
# 5  A-18-00  854.076  21.04370 -9999.0 -9999.0000   85.1543  153.1469       5
# 6  A-18-00  854.229  21.92050 -9999.0     0.2201   85.8205  153.4092       5
# 7  A-18-00  854.381  25.51510 -9999.0     0.2458   86.4174  156.7850       5
# 8  A-18-00  854.534  30.74730 -9999.0 -9999.0000   86.6582  160.3057       5
# 9  A-18-00  854.686  33.71390 -9999.0 -9999.0000   86.4899  163.8390       5
#
#         GR     MSFL      NPHI       PEF  Perm_Buckles_UpAs      PHIE     RHOB  \
# ...

# %%
import numpy as np
df.replace(-9999, np.NaN, inplace = True)

# %%
df.head()
# Out:
#   wellName    DEPTH       CGR  CPERM    CPHI        DT      DTSM  Facies  \
# 0  A-18-00  853.010   9.99433    NaN     NaN   88.8155  141.6838     1.0
# 1  A-18-00  853.162  20.56400    NaN     NaN   99.0574  166.7016     5.0
# 2  A-18-00  853.314  31.71550    NaN     NaN  104.7870  182.5868     5.0
# 3  A-18-00  853.619  35.58090    NaN  0.4126   99.2912  178.6600     5.0
# 4  A-18-00  853.772  28.67900    NaN     NaN   91.7247  168.8887     5.0
#
#         GR     MSFL      NPHI       PEF  Perm_Buckles_UpAs      PHIE     RHOB  \
# 0  53.4034  2.36973  0.151655  4.399977           9.209792  0.146527  2.61065
# 1  72.0957  1.31614  0.231567  4.030700           1.601786  0.220162  2.47339
# 2  78.3783  1.20371  0.287493  3.732858           3.690761  0.276589  2.35818
# 3  58.2256  1.63194  0.269803  3.399365           4.512031  0.291632  2.30063
# 4  50.9648  1.69673  0.237844  3.353567           3.159364  0.265337  2.35175
#
#         RT       SWE ZONE_NAME net_gross
# ...

# %%
df.describe()
# Out:
#              DEPTH          CGR         CPERM        CPHI           DT  \
# count  1100.000000  1100.000000     77.000000  239.000000  1076.000000
# mean    937.087017    22.064474   1323.846814    0.300029   102.717740
# std      48.459099    14.814662   3135.487888    0.086910    25.436151
# min     853.010000    -1.820080      0.010000    0.014400    49.315200
# 25%     895.186000    10.993825      4.360000    0.265000    81.672525
# 50%     937.058000    19.478800     66.847839    0.327000    97.973950
# 75%     978.930000    30.318275   1789.880005    0.358979   119.744250
# max    1020.950000    77.795400  24967.240230    0.431600   177.691000
#
#               DTSM      Facies           GR         MSFL         NPHI  \
# count  1100.000000  714.000000  1100.000000  1100.000000  1100.000000
# mean    229.143479    4.126050    33.918802     1.024971     0.285378
# std      79.039704    1.457512    13.667024     1.872884     0.054746
# ...

# %% [markdown]
# Evaluando la data perdida o nula
#
# 1. isnull()
# Propósito: Detectar valores nulos (NaN).
#
# 2. notnull()
# Propósito: Detectar valores no nulos.
#
# 3. dropna()
# Propósito: Eliminar las filas o columnas que contienen valores nulos (NaN).
#
# 4. fillna()
# Propósito: Rellenar los valores nulos (NaN) con algún valor específico.

# %%
miss_data = df.isnull()
miss_data
# Out:
#       wellName  DEPTH    CGR  CPERM   CPHI     DT   DTSM  Facies     GR  \
# 0        False  False  False   True   True  False  False   False  False
# 1        False  False  False   True   True  False  False   False  False
# 2        False  False  False   True   True  False  False   False  False
# 3        False  False  False   True  False  False  False   False  False
# 4        False  False  False   True   True  False  False   False  False
# ...        ...    ...    ...    ...    ...    ...    ...     ...    ...
# 1095     False  False  False   True   True  False  False    True  False
# 1096     False  False  False   True   True  False  False    True  False
# 1097     False  False  False   True   True  False  False    True  False
# 1098     False  False  False   True   True  False  False    True  False
# 1099     False  False  False   True   True  False  False    True  False
#
#        MSFL   NPHI    PEF  Perm_Buckles_UpAs   PHIE   RHOB     RT    SWE  \
# ...

# %%
miss_data = df.notnull()
miss_data
# Out:
#       wellName  DEPTH   CGR  CPERM   CPHI    DT  DTSM  Facies    GR  MSFL  \
# 0         True   True  True  False  False  True  True    True  True  True
# 1         True   True  True  False  False  True  True    True  True  True
# 2         True   True  True  False  False  True  True    True  True  True
# 3         True   True  True  False   True  True  True    True  True  True
# 4         True   True  True  False  False  True  True    True  True  True
# ...        ...    ...   ...    ...    ...   ...   ...     ...   ...   ...
# 1095      True   True  True  False  False  True  True   False  True  True
# 1096      True   True  True  False  False  True  True   False  True  True
# 1097      True   True  True  False  False  True  True   False  True  True
# 1098      True   True  True  False  False  True  True   False  True  True
# 1099      True   True  True  False  False  True  True   False  True  True
#
#       NPHI   PEF  Perm_Buckles_UpAs  PHIE  RHOB    RT   SWE  ZONE_NAME  \
# ...

# %% [markdown]
# La función msno.matrix(df) pertenece a la biblioteca missingno (abreviada como msno), que es una herramienta visual para analizar valores faltantes o nulos en los datos de un DataFrame de pandas.

# %%
pip install missingno
# Out:
# ...
#
# ...

# %% [markdown]
# Barra blanca: Representa los valores faltantes (NaN) en las filas del DataFrame.
#
# Barra gris: Representa los valores presentes (datos no nulos) en el DataFrame.

# %%
import missingno as msno

msno.matrix(df,figsize=(10,5), fontsize = 10, color= (0.6, 0.6, 0.5))
# Out:
# <Axes: >

# %%
msno.bar(df,figsize= (10,5), fontsize= 10, color = (0.5,0.7,0.5),  sort= 'descending')
# Out:
# <Axes: >
